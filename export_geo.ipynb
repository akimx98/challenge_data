# %% [markdown]
# # MathAData - Géométrie dans le plan, droites

# %% [markdown]
# ## Classification des images de 2 et de 7

# %% [markdown]
# !!! abstract But du TP
# Dans ce Notebook, nous allons construire un algorithme qui estime si un 2 ou un 7 est écrit sur une image.
# ![2_7.png](attachment:2_7.png)
# !!!

# %% [markdown]
# !!! tip Exécuter une cellule
# Pour commencer, cliquez sur la cellule de code ci-dessous puis appuyez sur le bouton <span style="display: inline-block; margin: auto 1rem;">![executer.png](attachment:executer.png)</span> ou les touches Majuscule puis Entrée de votre clavier.
# Lorsque le code aura été executé, un nombre apparaîtra entre les crochets sur la gauche : <span style="display: inline-block; margin: auto 1rem;">![cellule_executee.png](attachment:cellule_executee.png)</span>
# !!!

# %%
from utilitaires_geo import *

# %% [markdown]
# ## I. Point de départ

# %% [markdown]
# !!! tip Fonctionnement d'un algorithme
# Un algorithme reçoit une ou plusieurs données, effectue des opérations, et donne une réponse.
# ![algo_blackbox.png](attachment:algo_blackbox.png)
# !!!
# !!! question Répondre au problème
# L'algorithme que nous devons construire doit répondre 2 ou 7. Comment donner la bonne réponse environ **50% du temps** sans faire de calcul ?
# **Remplacez les `...`** dans la cellule suivante par la réponse $\hat r$ donnée par votre algorithme pour chaque image **puis exécutez**.
# !!!

# %%
def algorithme(d):
    return ...

# NE PAS TOUCHER CETTE LIGNE
validation_algorithme_fixe()

# %% [markdown]
# !!! info Le score : un moyen d'évaluer votre algorithme
# Le score est le taux d'erreur de votre algorithme. Plus il est bas meilleur est votre solution.
# On calcule le pourcentage d'erreur avec :
# $$\frac{\text{Nombre d'images mal classées}} {\text{Nombre total d'images}} \times 100$$
# Une image mal classée est une image pour laquelle l'algorithme a donné une prédiction différente de la vraie classe de l'image :
# $$\hat r \neq r$$
# !!!
# !!! tip Exécutez la cellule suivante
# Vous allez calculer votre score à la main sur 10 images. **Exécutez la cellule suivante** pour afficher les 10 premières images.
# !!!

# %%
affichage_dix()

validation_execution_calcul_score()

# %% [markdown]
# !!! question Quel est votre score sur ces 10 images ?
# Calculez le pourcentage d'erreur de votre algorithme sur les 10 premières images. **Remplacez les `...`** dans la cellule suivante par votre réponse (uniquement le nombre sans le %) **puis exécutez**.
# !!!

# %%
score_10 = ...

# NE PAS TOUCHER CETTE LIGNE
validation_question_score_fixe()

# %% [markdown]
# !!! tip Score sur toutes les images
# **Exécutez la cellule suivante** pour calculer votre pourcentage d'erreur sur l'ensemble des images.
# !!!

# %%
calculer_score_etape_1()

# %% [markdown]
# ## II. Image numérique

# %% [markdown]
# !!! abstract Qu'est ce qu'une image ?
# Pour améliorer notre score notre algorithme doit "regarder" l'image. On doit comprendre ce qu'est l'image pour l'ordinateur.
# !!!
# !!! tip Calcul sur l'image
# Pour l'ordinateur, une image est un tableau de nombres. Chaque nombre correspond à un pixel de l'image. Chaque pixel vaut entre 0 et 255, 0 pour noir et 255 pour blanc.
# ![pixels.png](attachment:pixels.png)
# **Exécutez la cellule suivante pour afficher une image $d$.**
# !!!

# %%
affichage(d)
affichage_tableau(d)

validation_execution_affichage()

# %% [markdown]
# !!! question Quelle est la valeur du pixel (17,15) ?
# Lisez dans le tableau la valeur du pixel en position (17,15) et complétez sa valeur **à la place des `...`** dans la cellule ci-dessous **puis exécutez**.
# La première coordonnée est le numéro de ligne, la deuxième le numéro de colonne.
# !!!

# %%
pixel = ...

# NE PAS TOUCHER CETTE LIGNE
validation_question_pixel()

# %% [markdown]
# !!! question Transformez le pixel (17,15) en pixel noir
# **Remplacez ci-dessous les `...`** par la nouvelle valeur à donner au pixel pour qu'il soit noir **puis exécutez**.
# !!!

# %%
d[17,15] = ...

# NE PAS TOUCHER CES LIGNES
validation_question_pixel_noir()
affichage(d,(17,15))
affichage_tableau(d,(17,15))

# %% [markdown]
# ## III. Caractéristiques

# %% [markdown]
# ### III.1 Calcul des caractéristiques

# %% [markdown]
# !!! info Caractéristique d'une image
# Pour améliorer notre score, notre algorithme doit maintenant utiliser l'image au lieu de répondre au hasard.
# ![caracteristique_2.png](attachment:caracteristique_2.png)
# Les caractéristiques notées $k_1, k_2, ...$ permettent de simplifier l'image en gardant peu de nombres.
# **La moyenne** est un bon exemple de caractéristique car elle permet de résumer plusieurs valeurs en une seule.
# !!!

# %% [markdown]
# ![image_7_carre_marge.png](attachment:image_7_carre_marge.png)
# ![tableau_7_carre.png](attachment:tableau_7_carre.png)
# !!! question Calculez la moyenne sur les pixels rouges
# Calculez la moyenne des pixels de la zone surlignée en rouge. Donnez votre réponse **à la place des `...`** dans la cellule ci-dessous **puis exécutez**.
# !!!

# %%
k = ...

# NE PAS TOUCHER CETTE LIGNE
validation_question_moyenne()

# %% [markdown]
# !!! tip Moyenne sur 2 zones différentes
# Nous allons commencer avec deux caractéristiques de référence : la moyenne sur la moitié haute de l'image et la moyenne sur la moitié basse.
# ![image_2_caracs.png](attachment:image_2_caracs.png)
# **Exécutez la cellule suivante** pour définir la fonction `caracteristique` qui calcule ces deux valeurs
# !!!

# %%
zone_1 = [(0,0), (13,27)]
zone_2 = [(14,0), (27,27)]

def deux_caracteristiques(d):
    k1 = moyenne_zone(d, zone_1[0], zone_1[1])
    k2 = moyenne_zone(d, zone_2[0], zone_2[1])
    return (k1, k2)

affichage_2_geo()
validation_execution_2_caracteristiques()

# %% [markdown]
# !!! question Quelle image correspond à chaque couple ($k_1,k_2$) ?
# On a calculé pour les deux images ci-dessus leurs caractéristiques $(k_1, k_2)$. Regardez les deux images et le tableau pour déduire quelle image correspond à chaque couple de moyennes $(k_1, k_2)$.
# **Remplacez les `...`** dans la cellule suivante avec 2 et 7 dans le bon ordre **puis exécutez**.
# !!!

# %%
r1 = ...
r2 = ...

# NE PAS TOUCHER CETTE LIGNE
validation_question_2_caracteristiques()

# %% [markdown]
# ### III.2 Visualisation dans le plan

# %% [markdown]
# !!! info Visualisation dans le plan
# Nous avons maintenant 2 valeurs $(k_1, k_2)$ associées à chaque image. Nous pouvons placer les images dans un plan en utilisant $k_1$ et $k_2$ comme coordonnées.
# **Exécutez la cellule suivante** pour afficher les points correspondant à 2 images.
# !!!

# %%
tracer_2_points()
validation_execution_2_points()

# %% [markdown]
# !!! question Donnez les coordonnées $(k_1, k_2)$ des points A et B
# Complétez les coordonnées dans la cellule suivante **puis exécutez**. On acceptera des valeurs arrondies.
# !!!

# %%
A = (..., ...)

B = (..., ...)

# NE PAS TOUCHER CETTE LIGNE
validation_question_2_points()

# %% [markdown]
# !!! info Nuages de points
# Nous allons maintenant étudier la répartition dans le plan de 2 et des 7. Plus notre caractéristique est discriminante, plus on peut observer 2 nuages (groupes) de points distincts
# **Exécutez la cellule suivante** pour afficher les points correspondant aux 200 premières images de l'ensemble d'entraînement.
# !!!

# %%
tracer_200_points()
validation_execution_200_points()

# %% [markdown]
# !!! question Quel nuage de point correspond à quelle classe d'image ?
# A votre avis, les points de couleur bleue correspondent aux images de 2 ou de 7 ? **Remplacez les `...`** dans la cellule suivante avec 2 ou 7 dans le bon ordre **puis exécutez**
# !!!

# %%
classe_points_bleus = ...
classe_points_oranges = ...

# NE PAS TOUCHER CETTE LIGNE
validation_question_couleur()

# %% [markdown]
# ### III.3 Classification

# %% [markdown]
# !!! info Classification
# La classification est la dernière étape de l'algorithme. Il faut trouver un moyen de donner une réponse 2 ou 7 à partir des caractéristiques $k_1, k_2$.
# ![classification_2.png](attachment:classification_2.png)
# !!!
# !!! info Découpage du plan par une droite
# En deux dimensions, on peut utiliser une droite pour séparer les points en deux groupes. L'équation de la droite est de la forme
# $$k_2 = mk_1 + p$$
# On exprime $k_2$ en fonction de $k_1$ avec deux paramètres :
# - $m$ : le coefficient directeur de la droite
# - $p$ : l'ordonnée à l'origine de la droite donc la valeur de $k_2$ pour $k_1 = 0$
#
# **Exécutez la cellule suivante** pour voir le découpage par une droite avec les points pour 10 images.
# !!!

# %%
tracer_10_points_droite()
validation_execution_10_points()

# %% [markdown]
# !!! question Quel est le pourcentage d'erreur sur ce schéma ?
# Calculez le score pour ces 10 images et cette droite. Les points au dessus de la droite sont classés comme 2 par l'algorithme et ceux en dessous comme des 7.
# **Remplacez les `...`** dans la cellule suivante par votre réponse (uniquement le nombre sans le %) **puis exécutez**.
# !!!

# %%
score_10 = ...

# NE PAS TOUCHER CETTE LIGNE
validation_question_score_droite()

# %% [markdown]
# !!! question Trouvez une droite permettant d'obtenir moins de 8% d'erreur
# Ajustez les paramètres $m$ et $p$ pour trouver une bonne droite séparatrice. Le pourcentage d'erreur est la proportion de points d'un groupe qui sont du mauvais côté de la droite.
# Quand vous aurez trouvé une bonne droite, **exécutez la cellule suivante** pour passer à la suite.
# !!!

# %% [markdown]
# <div style="text-align: center; font-weight: bold; font-size: 2rem;">Score : <span id="score">...</span></div>
#
# <div>
#   <canvas id="chart"></canvas>
# </div>
#
# <div>
#     <label for="slider_m" id="label_m"></label>
#     <input type="range" min="0" max="5" value="2" step="0.1" class="slider" id="slider_m">
#     <label for="slider_p" id="label_p"></label>
#     <input type="range" min="-50" max="50" value="0" step="0.1" class="slider" id="slider_p">
# </div>

# %%
calculer_score_etape_2()

# %% [markdown]
# !!! info Pourquoi les 2 scores sont-ils légèrement différents ?
# Dans la première étape, vous avez ajusté les paramètres $m$ et $p$ de la droite pour avoir le score le plus bas possible. En IA, c'est l'étape de l'apprentissage. Le deuxième score est calculé sur d'autres images : c'est l'étape de test.
# Ces deux étapes sont importantes pour vérifier que l'algorithme n'a pas appris par coeur les images d'entraînement et qu'il sait généraliser à des images qu'il n'a pas vu pendant l'apprentissage.
# !!!

# %% [markdown]
# #### Détail du calcul de l'erreur

# %% [markdown]
# !!! abstract Classification linéaire
# Pour faire la classification avec la droite :
# - Nous avons choisi 2 paramètres $m$ et $p$ pour définir une droite séparant les deux classes
# - Nous avons déterminé que l'algorithme devait estimer $\hat r = 2$ pour les points au dessus de la droite
# ![classification_2d.png](attachment:classification_2d.png)
# !!!
# !!! info Comment l'ordinateur fait-il pour savoir si un point est au dessus de la droite ?
# L'ordinateur ne peut pas faire de comparaison visuelle. Il doit donc faire des calculs avec les coordonnées des points et l'équation de la droite.
# **Exécutez la cellule suivante** pour voir un exemple.
# !!!

# %%
tracer_point_droite()
validation_execution_point_droite()

# %% [markdown]
# !!! question Quelles sont les coordonnées du point M ?
# On cherche à savoir si le point $A$ est sous ou au-dessus de la droite, à partir de ses coordonnées.
# On introduit le point $M$ : même abscisse que $A$ mais appartient à la droite.
# En utilisant l'équation de la droite, complétez les coordonnées de $M$ dans la cellule ci-dessous.
# !!!

# %%
abscisse_M = ...
ordonnee_M = ...

# NE PAS TOUCHER CETTE LIGNE
validation_question_equation()

# %% [markdown]
# ### Essayer de trouver 2 meilleures caractéristiques !

# %% [markdown]
# !!! tip Définir vos propres caractéristiques
# Vous pouvez définir vos propres caractéristiques en changeant les zones choisies pour calculer les moyennes.
# On définit la 1ère caractéristique $k_1$ comme la moyenne sur un rectangle entre les point $A_1$ (coin en haut à gauche du rectangle) et $B_1$ (coin en bas à droite du rectangle).
# De même on définit la 2ème caractéristique $k_2$ comme la moyenne sur un rectangle entre les point $A_2$ (coin en haut à gauche du rectangle) et $B_2$ (coin en bas à droite du rectangle).
# !!!

# %% [markdown]
# !!! question Changer les zones choisies pour définir vos propres caractéristiques
# Changez les coordonnées des points $A_1$, $B_1$, $A_2$ et $B_2$ pour définir vos deux propres caractéristiques.
# Vous pouvez **exécutez la cellule** pour voir l'exemple puis modifier les coordonnées.
# !!!

# %%
A_1 = (4, 3)       # <- essayer d'autres coordonnées !
B_1 = (7, 24)     # <- essayer d'autres coordonnées !


A_2 = (22, 3)       # <- essayer d'autres coordonnées !
B_2 = (25, 24)     # <- essayer d'autres coordonnées !



# NE PAS TOUCHER CES LIGNES SAUF SI VOUS SAVEZ CE QUE VOUS FAITES
def deux_caracteristiques(d):
        # La fonction moyenne_zone cacule la moyenne des pixels entre les points A et B
        k1 = moyenne_zone(d, A_1, B_1)
        k2 = moyenne_zone(d, A_2, B_2)
        return k1, k2

affichage_2_cara(d, d_train[2], A_1, B_1, A_2, B_2, True)

# NE VRAIMENT PAS TOUCHER CETTE LIGNE
validation_execution_caracteristiques_custom()

# %% [markdown]
# !!! question Trouvez la meilleure droite
# Ajustez les paramètres $m$ et $p$ pour trouver une bonne droite séparatrice. Le pourcentage d'erreur est la proportion de points d'un groupe qui sont du mauvais côté de la droite.
# Quand vous aurez trouvé une bonne droite, **exécutez la cellule suivante** calculer votre score de test.
# !!!

# %% [markdown]
# <div style="text-align: center; font-weight: bold; font-size: 2rem;">Score : <span id="score_custom">...</span></div>
#
# <div>
#   <canvas id="chart_custom"></canvas>
# </div>
#
# <div>
#     <label for="input_m"> m : </label>
#     <input type="number" value="1" step="0.1" id="input_m">
#     <label for="input_p">p : </label>
#     <input type="number" value="0" step="0.1" id="input_p">
# </div>

# %%
calculer_score_etape_3()

# %% [markdown]
# !!! abstract Fin du Notebook
# Dans ce TP, vous avez :
#
# - Utilisé deux caractéristiques pour chaque image
# - Placé les images dans un plan en utilisant ces deux valeurs comme coordonnées
# - Utilisé une droite pour séparer les points en deux groupes
# - Optimisé les paramètres de la droite pour minimiser votre erreur
#
# Continuez à chercher des bonnes zones pour améliorer votre score. Vous pouvez faire jusqu'à moins de 3% d'erreur !
# !!!
