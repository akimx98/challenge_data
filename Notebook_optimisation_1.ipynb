# %% [markdown]
# # Challenge Data - Descente de dérivée

# %% [markdown]
# ## Importations

# %% [markdown]
# On commence par importer les données dont nous aurons besoin :

# %%
from utilitaires_optim import *

# %% [markdown]
# # I. Descente de dérivée

# %% [markdown]
# ## I.1 La dérivée par incréments

# %% [markdown]
# Afin d'estimer la dérivée $f'(\theta_0)$ en un point $\theta_0$, on peut calculer le taux d'accroissement de la fonction $f$ entre $\theta_0$ et $\theta_0+\eta$.
# Pour $\eta$ assez petit, on aura:
#
# $$f'(\theta_0)\approx \frac{f(\theta_0+\eta)-f(\theta_0)}{\eta}.$$
#
# <b><font color=red> Connaissant $\eta$ (la variable `eta`) les valeurs de la fonctions $f(\theta_0+\eta)$ (la variable `feta`) $f(\theta_0)$ (la variable `f0`)
#
# Compléter la fonction `estimation_derivée(eta,feta,f0)` qui estime $f'(\theta_0):$</font></b>

# %%
def estimation_derivée(eta,feta,f0):
    return (feta-f0)/...

# %% [markdown]
# Le taux d'accroissement $\frac{f(\theta_0+\eta)-f(\theta_0)}{\eta}$ est la pente (ou coefficient directeur), de la droite qui passe par les points $(\theta_0,f(\theta_0))$ et $(\theta_0+\eta,f(\theta_0+\eta))$.
#
# L'équation de cette droite est:
# $$y(\theta) = \frac{f(\theta_0+\eta)-f(\theta_0)}{\eta}(\theta-\theta_0)+f(\theta_0).$$
#
# <b><font color=red> La fonction `approx_derivéee(eta)` trace la fonction $y(\theta)$. Faire varier `eta` jusqu'à ce que le taux d'accroissement soit égal à la dérivée. </font></b>

# %%
eta  = 1 # <-- faire varier
approx_derivee(eta)

# %% [markdown]
# ## I.2 La parabole

# %% [markdown]
# On déclare les variables a, b et c

# %%
a = 1
b = 2
c = 3

# %% [markdown]
# <b><font color=red> Définir une fonction `f(x)`, qui renvoie $ax^2+bx+c$ : </font></b>

# %%
def f(x):
    return a*x**2+b*x+c

# %% [markdown]
# ```
# def f(x):
#   return a*x**2+b*x+c
# ```

# %% [markdown]
# <b><font color=red> Définir une fonction `df(x)`, qui renvoie $2ax+b$ (la dérivée $f'$ ) : </font></b>

# %%
def df(x):
    return ...

# %% [markdown]
# ```
# def df(x):
#   return 2*a*x+b
# ```

# %% [markdown]
# On rappelle que la descente de dérivée construit la suite:
# $$\theta_{n+1} = \theta{n}-\alpha f'(\theta_n)
# $$
#
# On importe une fonction `descente(theta_0,alpha,N)`, qui prend en entrée $\theta_0$, $\alpha$, $N$. La fonction renvoie la liste [$\theta_0$,$\theta_1$,....,$\theta_N$].

# %% [markdown]
# <b><font color=red> Utiliser la fonction `descente` pour $\theta_0 = 1$ et $\alpha=0.1$, pendant $N =10$ étapes. </font></b>

# %%
theta_0 = ...
alpha = ...
N = ...
theta = descente(theta_0,alpha,N)

# %% [markdown]
# <b><font color=red>En utilisant la fonction `print(...)`, afficher la valeur  $\theta_N$ </font></b>
#
# <b>⚠️ Attention  : </b> En Python les indices négatifs parcourent la liste en sens inverse.Ainsi le dernier élément d'une liste est donc liste[-1].
# </div>

# %%
...

# %% [markdown]
# ```
# print(theta[-1])
# ```

# %% [markdown]
# <b><font color=red>En utilisant la fonction `print(...)` et la fonction `f(x)`, afficher la valeur  $e(\theta_N$) </font></b>

# %%
...

# %% [markdown]
# ```
# print(e(theta[-1]))
# ```

# %% [markdown]
# On peut visualiser la descente de gradient, en utilisant la fonction `affichage_descente(theta)`.

# %%
affichage_descente(theta)

# %% [markdown]
# <b><font color=red> Pour $N=6$, et $\theta_0 = -2$, trouver le $\alpha$ qui renvoie la valeur minimale de $f(\theta_N)$: </font></b>

# %%
alpha = 0.5

theta_0 = -2
N = 6
theta = descente(theta_0,alpha,N)
print(r'$f(\theta_N)$' +' = '+str(f(theta[-1])))
affichage_descente(theta)
# Out:
# $e(\theta_N)$ = 2.0
